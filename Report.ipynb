# %% [markdown]
# # Introduction

# %% [markdown]
# ## Problem Statement:
#
# As a newly formed state in India, Andhra Pradesh wants to build its capital city. Given that it has a chance to plan and build its city from scratch, Government wants to study big cities like Toronto, San Francisco, New York e.t.c. and plan for must haves in the city and connectivity of suburbs to the city keeping expansion in future . One of their cities of target was Toronto and wanted to study how many public places of interest are planned for the city and outskirts, how many parks,railway stations, public community halls, libraries, per Borough and neighborhood e.t.c. They wanted to do study of several other similar cities and come up with the plan.
#
# ## Audience:
# Government of Andhra Pradesh City planning department
#
# ## Problem Attempted to Solve:
# Here we help with study of city Toronto geographical plan

# %% [markdown]
# # Data Description

# %% [markdown]
# Given that we need to study city of Toronto for its public buildings, we will get this information from several sources. One of them will be four square venue exploration api.
#
# Other sources are https://en.wikipedia.org/wiki/List_of_hospitals_in_Toronto#:~:text=There%20are%20over%20forty%20hospitals,with%20the%20University%20of%20Toronto. and https://www.tdsb.on.ca/About-Us#:~:text=Quick%20Facts,approximately%20247%2C000%20students%20each%20year.&text=There%20are%20over%20120%20languages%20spoken%20by%20TDSB%20students%20and%20their%20families.
# https://en.wikipedia.org/wiki/Toronto_subway
# https://en.wikipedia.org/wiki/GO_Transit
#
# We will specifically be looking at places of public interest like train stations, community halls, parks, indoor stadiums, Schools and Hospitals etc which form government's infrastructure.
#
# Ill be using Four Square Explore venue api with Toronto’s neighbourhood's latitude and longitude details and neighbourhood's in Suburbs as well to better plan the city and outskirts. Ill also be using Wikipedia page for table listing hospitals and information from TDSB page for school information in addition to four square results to get to better conclusions. Public Transapotation is pulled from wikipedia as additional sources.
#
# Ill be using Four Square trending venue api during morning and evening rush times with Toronto’s coordinates to get specifically public transit information
#
# We will get prospect city’s current population density and Toronto’s + GTA's population density to provide recommendations. We will arrive at an optimum number of public service buildings for the population density of City that is in planning.

# %% [markdown]
# # Methodology

# %% [markdown]
# We will start with importing all the required libraries to analyse and display the data the way we want.
#
# We will then start working with the Wikipedia page which has Borough information and postal code for all neighbourhoods. We will scrape the data from this page https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M  and clean it. We will then add lattitude and longitude information to that data set. There is information for 10 unique Boroughs in total.
#
# We concentrate on Borough's end with Toronto and call them downtown Toronto, everthing else becomes outskirts of downtown Toronto whic is catlled GTA. We will get near by venues and their categories for all the neighbourhoods in downtown and GTA and store it in two different dataframes.
#
# We make a unique list of categories available in both these dataframes. Frome this unique list we will filter in categories that has words parks, play grounds, railway stations, airports etc and store them in filtered dataframes. These dataframes are then converted into dummy codes for each column. We will then count the occurances of these in each neighbourhood and Borough's and create a total row for filtered downtown dataframe and GTA dataframe.
#
# From data for hospitals, we will scrape the first table from this page https://en.wikipedia.org/wiki/List_of_hospitals_in_Toronto#:~:text=There%20are%20over%20forty%20hospitals,with%20the%20University%20of%20Toronto. and clean it. We will then make 2 subset dataframes for downtown toronto which consists of Old Toronto area and rest for GTA. We will count the number of hospitals in each data frame as total number of hospitals for those areas
#
# For Schools the data is directly available from TDBS website but there isnt a clear distinction on how many belong to downtown Toronto and how many for GTA
#
# For public transit, I am running the trending Places api from foursquare using the lattitude and longitude of downtown Toronto. But since the api was always returning empty json, I pulled the information from this wikipedia page https://en.wikipedia.org/wiki/Toronto_subway. There are 75 subway stations in downtown Toronto, while GTA has 66 Go stations which is main transportation used by commuters in GTA, https://en.wikipedia.org/wiki/GO_Transit

# %% [markdown]
# # Results & Discussion

# %% [markdown]
# After scraping the data for Borough's in Toronto from wikipedia page and adding lattitude & longitude details, the data looks like the table below.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# The data is then split into 2 smaller dataframes containing information for downtown Toronto and Greater Toronto Area(GTA) as shown below

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# The venues and venue categories for each neighbourhoods in Toronto and GTA dataframes form new data frames and they look like below

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# From the unique list of the categories for the venues. The ones we are interested in are
# ['Light Rail Station', 'Train Station', 'History Museum','Baseball Field','College Arts Building', 'Airport','Airport Terminal','Airport Gate','Bus Station','Medical Center','Metro Station', 'Athletics & Sports','Playground','Skate Park','Bus Line','Soccer Field','Skating Rink','Basketball Stadium','Music Venue','Performing Arts Venue', 'Monument / Landmark', 'Park', 'Dog Run', 'Hockey Arena','Historic Site','Fountain','Museum','Art Museum','Garden']

# %% [markdown]
# Public places in Toronto & GTA form filetred dataframes and they are

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# Visualisation of these venues on Map

# %% [markdown]
# ![8.png](attachment:8.png)

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# Dummied data frames total per Borough for Toronto & GTA dataframe

# %% [markdown]
# ![10.png](attachment:10.png)

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# Bar plots for the totals in Toronto & GTA

# %% [markdown]
# ![12.png](attachment:12.png)

# %% [markdown]
# ![13.png](attachment:13.png)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Population density of GTA is 849 people per square kilometer. There are 37 parks, 5 play grounds,1 Soccer Feild, 2 Baseball feilds and 1 major publicly maintained fountain.
#
# Population density of downtown Toronto is 8,210 people per square kilometer. There are 29 parks, 3 play grounds, 2 Basket Ball stadiums, 2 Skate parks, 1 major Train station(Union Station).
#
# There are 75 subway stations in downtown and 66 train stations in GTA.
#
# Total 35 hospitals, 16 of them are in downtown Toronto and 19 are in GTA. Based on population Density, this sounds reseaonable
#
# 583 schools in total. 473 Elementary Schools and 110 Secondary Schools

# %% [markdown]
# # Recommendations

# %% [markdown]
# Population density of capital city of Andhra Pradesh is 3800 people per square kilometer which is almost half of the size of Toronto. So, my recommendation would be to size the public places accordingly for now and allocate for expansion in future.
#
# For Downtown:
# 15 parks, 2 play grounds, 1 Basket Ball stadiums, 1 Skate parks, 8 hospitals, 40 Metro stations, 150 schools and 1 major publicly maintained fountain.
#
# For Suburbs:10 parks, 3 play grounds, 1 Soccer Feild, 1 Baseball feilds,30 Metro Stations, 100 schools, 10 hospitals
#
# Note: In India, subways are called Metro's and they extend to Suburbs also.
